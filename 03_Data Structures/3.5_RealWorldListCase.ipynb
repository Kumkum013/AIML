# %%
to_do_list=["buy groceries","clean the house","pay bills"]

#adding to task

to_do_list.append("scheduled meetings")
to_do_list.append("go for a run")

#removing a completed task
to_do_list.remove("clean the house") 

#checking if the task is in the list
if "pay bills" in to_do_list:
    print("do'nt forget to pay the utility bills")
print(" to_do_list remaining")
for task in to_do_list:
    print(f"-{task}")
# Out:
# do'nt forget to pay the utility bills
#  to_do_list remaining
# -buy groceries
# -pay bills
# -scheduled meetings
# -go for a run

# %%
# organising student grades
grades=[85,92,78,90,88]

#adding a new grade
grades.append(95)

#calculating the avg grade
avg_grade=sum(grades)/len(grades)
print(f"average grade:{avg_grade}")

#finding highest and lowest grades

highest_grade= max(grades)
lowest_grade= min(grades)
print(f"highest grade:{highest_grade}")
print(f" lowest grade:{lowest_grade}")
# Out:
# average grade:88.0
# highest grade:95
#  lowest grade:78

# %%
#collecting user feedback
feedback= ["great service!","very satisfied","could be better","excellencent experience "]

#adding new feedback
feedback.append("not happy with the service")

#counting specific feedback
positive_feedback_count=sum(1 for comment in feedback if "great" in comment.lower()or "excellent")

print(f"positive feedback count :{positive_feedback_count}")

#printing all feedback
print("user feedback:")
for comment in feedback:
    print(f"-{comment}")
# Out:
# positive feedback count :5
# user feedback:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 15
#      13 print("user feedback:")
#      14 for comment in feedback:
# ---> 15     print(f"-{comment}")
#
# Cell In[2], line 15
#      13 print("user feedback:")
#      14 for comment in feedback:
# ---> 15     print(f"-{comment}")
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1112, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1090, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# ...
